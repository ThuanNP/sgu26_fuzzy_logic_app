# %% [markdown]
# # Thực hành trí tuệ nhân tạo buổi 1
# ## Nội dung thực hành

# %% [markdown]
# ### In chữ ra màn hình

# %%
# Lệnh 1 - Xuất chữ
print("Hello, Python world!")
# Out:
# Hello, Python world!

# %%
# Lệnh 2 - Chạy file ex0_hello_world.py
# %run ../ex0_hello_world.py
# Out:
# Hello, Python world!

# %%
# Lệnh 3 - Chạy file ex1_calc.py
# %run ../ex1_calc.py
# Out:
# Calculator Basic
# Mời bạn nhập số a:  123
# Mời bạn nhập số b:  456
# c = 123 + 456 = 579

# %%
# Lệnh 4 - Tính diện tích hình tròn
# %run ../ex3_circle.py
# Out:
# Tính chu vi hình tròn
# Mời ban nhập bán kính hình tròn:  5
# Chu vi hình tròn là: 31.40, diện tích hình tròn là: 78.50

# %% [markdown]
# # Kết thúc
